# %%
from ultralytics import YOLO
# from ultralytics.yolo.v8.detect.predict import DetectionPredictor

import cv2

model = YOLO("best.pt")
# cap = cv2.VideoCapture(0)
results = model.predict(source='firee.mp4', show = True, save = True)
print(results)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/594) /Users/shukurullomeliboyev2004/Desktop/fire_detection/firee.mp4: 640x384 (no detections), 175.6ms
# video 1/1 (frame 2/594) /Users/shukurullomeliboyev2004/Desktop/fire_detection/firee.mp4: 640x384 (no detections), 161.1ms
# video 1/1 (frame 3/594) /Users/shukurullomeliboyev2004/Desktop/fire_detection/firee.mp4: 640x384 (no detections), 190.6ms
# ...
